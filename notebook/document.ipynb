# %% [markdown]
# ### Data Ingestion Pipeline

# %%
### Document Structure

from langchain_core.documents import Document

# %%
### Basic Harcoded Document
doc = Document(
    page_content="This is the main text content of the data",
    metadata={
        "source" : "example.txt",
        "author" : "soham pasalkar",
        "pages"  :  1,
        "date_created" : "2026-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'author': 'soham pasalkar', 'pages': 1, 'date_created': '2026-01-01'}, page_content='This is the main text content of the data')

# %%
## Create a simple txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt" : """Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",

    
    "../data/text_files/machine_learning.txt" : """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems"""
}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("Sample text files created!")
# Out:
# Sample text files created!

# %%
### Document Loader

from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# /var/folders/vh/gy7ltq412bn_ln9h0p7jwkcr0000gn/T/ipykernel_42957/3109289450.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Document Loader

from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False

)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.'),
#  Document(metadata={'source': '../data/text_files/machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems')]

# %%
### Document Loader

from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls= PyMuPDFLoader, ##loader class to use
    show_progress=False
)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Skia/PDF m140 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '../data/pdf/Pasalkar_Soham_HPAIR_2025_Acceptance.pdf', 'file_path': '../data/pdf/Pasalkar_Soham_HPAIR_2025_Acceptance.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': 'Pasalkar_Soham_HPAIR_2025_Acceptance', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='The Harvard College Project for Asian & International Relations \nOffice of the Presidents & Executive Board \n59 Shepard Street, Cambridge. MA 02138 \nUnited States of America \n \nDear Soham Pasalkar: \n \nCongratulations! We are excited to inform you that our Admissions Committee has selected you for the 2025 \nHPAIR Asia Conference at The University of Tokyo in Tokyo, Japan. On behalf of the entire team at the Harvard \nCollege Project for Asian and International Relations (HPAIR), please accept our warmest congratulations! \n \nOur team thoroughly reviews each written application and carefully considers every interview. We accept only those \nwho show the most significant promise and potential and will contribute most to our 2025 HPAIR Asia \nConference (ACONF). Based on your previous experiences, merit, and passion, we hope you will share your unique \nideas with fellow delegates worldwide at ACONF 2025. \n \nThis year’s Asia Conference theme is Reinventing Vitality: Momentum and Memory. HPAIR’s goal is to create a \nglobal community of individuals dedicated to collaborative achievement, and this year’s theme reflects our values of \nconservation, connectivity, and creativity. From understanding how to keep dynamics in society while embracing \nuniqueness in a globalized world, this conference invites participants to explore approaches to innovation. \n \nIn the past few years, our conferences have featured global business leaders (CEO of McKinsey & Co., COO of \nZoom), top government officials (former Vice President of the Philippines, U.S. Trade Representative, former \nChief Secretary of Hong Kong), international celebrities (Janice Koh, Anupam Tripathi), Nobel Prize winners \n(Muhammad Yunus, Seth Shelden), among many others! This upcoming conference will occur from August 20-24, \n2025, in Tokyo, Japan. It will allow you to engage with even more renowned speakers, network with fellow \ndelegates, and create lifelong memories and connections. \n \nAs the Co-Presidents of HPAIR, we want to congratulate you on your acceptance and warmly welcome you to the \nHPAIR community. We look forward to meeting you in August! \n \nWarmly, \nMichelle Jiang, Gulirano Almuratova, and Henry Chen \nCo-Presidents  \nThe Harvard College Project for Asian and International Relations (HPAIR) \n(E): presidents@hpair.org (W): www.hpair.org'),
#  Document(metadata={'producer': 'Skia/PDF m143 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '../data/pdf/Soham_Pasalkar_HCONF_Acceptance_Letter.pdf', 'file_path': '../data/pdf/Soham_Pasalkar_HCONF_Acceptance_Letter.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': 'Soham_Pasalkar_HCONF_Acceptance_Letter', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='The Harvard College Project for Asian & International Relations \nOffice of the Presidents & Executive Board \n59 Shepard Street, Cambridge. MA 02138 \nUnited States of America \n \nDear Soham Pasalkar: \n \nCongratulations! The admissions team at the Harvard College Project for Asian and International \nRelations (HPAIR) is overjoyed to let you know that we have selected you as a delegate for the 2026 \nHPAIR Harvard Conference!  \n \nThe team has diligently and carefully reviewed hundreds of written applications and numerous \ninterviews over the past few weeks. We only accept applicants who demonstrate genuine interest, \nexceptional promise, and who we believe will bring a valuable perspective to the 2026 HPAIR Harvard \nConference (HCONF). We have selected you because we believe you embody those valuable \ncharacteristics and will make a powerful contribution at HCONF 2026.  \n \nThe theme of this year’s HPAIR Conference is Emerging Horizons: Truth at Dawn, Hope at Dusk. At a \ntime with incredible uncertainty within the world, we are cognizant of the tremendous questions we all \nhave about where the future takes us, and believe that this conference will be inspirational in developing \nyour thinking as a future leader in our world. \u200b\n \nIn recent years, our conferences have featured global business leaders (CEO of McKinsey & Co., COO of \nZoom), high-ranking government officials (former Vice President of the Philippines, U.S. Trade \nRepresentative, former Chief Secretary of Hong Kong), renowned international celebrities (Janice Koh, \nAnupam Tripathi), and Nobel Prize laureates (Muhammad Yunus, Seth Shelden) among many others! \nThis upcoming conference will take place from February 6-8, 2026 at Harvard University, and will allow \nyou the opportunity to build lifelong connections and memories. \n \nAs the Co-Presidents of HPAIR, we personally want to congratulate you on your acceptance and warmly \nwelcome you to the HPAIR community. We look forward to meeting you in February! \n \nWarmly, \n \nNoah Plattner, Caroline Gao, Lucia Gallo \nCo-Presidents  \nThe Harvard College Project for Asian and International Relations (HPAIR)\u200b\n \n(E): presidents@hpair.org (W): www.hpair.org')]
